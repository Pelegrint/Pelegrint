# %% [markdown]
# <a href="https://colab.research.google.com/github/Pelegrint/Pelegrint/blob/main/simulador_atm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saldo = 1000.00
limite_saques = 3
numero_saques = 0

while True:
    print("\n---MENU BANCO---")
    print("1. Ver Saldo")
    print("2. Depositar")
    print("3. Sacar")
    print("4. Sair")

    opcao = input("Escolha uma opção:")

    if opcao == "1":
        print(f"Seu saldo atual é R${saldo:.2f}")

    elif opcao == "2":
        valor = float(input("Quanto deseja depositar?"))

        saldo += valor

        print("Depósito realizado!")

    elif opcao == "3":
        valor = float(input("Quanto deseja sacar? "))

        if valor > saldo :
            print("Saldo insuficiente")

        else:
            saldo -= valor
            numero_saques += 1
            print("Saque realizado com sucesso!")

    elif opcao == "4":
        print("Obrigado por usar nosso banco, até logo!")

        break

    else:
        print("Opção inválida, tente novamente.")
# Out:
# ---MENU BANCO---
# 1. Ver Saldo
# 2. Depositar
# 3. Sacar
# 4. Sair
# Escolha uma opção:3
# Quanto deseja sacar? 500
# Saque realizado com sucesso!
#
# ---MENU BANCO---
# 1. Ver Saldo
# 2. Depositar
# 3. Sacar
# 4. Sair
# Escolha uma opção:1
# Seu saldo atual é R$500.00
#
# ---MENU BANCO---
# 1. Ver Saldo
# 2. Depositar
# 3. Sacar
# 4. Sair
